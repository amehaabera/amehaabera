# %% [markdown]
# <a href="https://colab.research.google.com/github/amehaabera/amehaabera/blob/main/Detecting%20Money%20Laundering%20Using%20Machine%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Imports a range of libraries and modules for data manipulation, visualization, and machine learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import average_precision_score
from xgboost.sklearn import XGBClassifier
from xgboost import plot_importance, to_graphviz
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_auc_score ,roc_curve,auc
from sklearn.model_selection import GridSearchCV,StratifiedKFold
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.tree import export_graphviz
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #loading a dataset

# %%
df=pd.read_csv("/content/Fraud_Data.csv")

# %% [markdown]
# # Display the columns and their data types

# %%
df.columns
print(df.dtypes)
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldBalanceOrig    float64
# newBalanceOrig    float64
# nameDest           object
# oldBalanceDest    float64
# newBalanceDest    float64
# isFraud           float64
# isFlaggedFraud    float64
# dtype: object

# %%
df = df.rename(columns={'oldbalanceOrg':'oldBalanceOrig', 'newbalanceOrig':'newBalanceOrig', 'oldbalanceDest':'oldBalanceDest', 'newbalanceDest':'newBalanceDest'})

# %%
df1=pd.read_csv("/content/Fraud_Data.csv")
df1=df1.rename(columns={'oldbalanceOrg':'oldBalanceOrig', 'newbalanceOrig':'newBalanceOrig', 'oldbalanceDest':'oldBalanceDest', 'newbalanceDest':'newBalanceDest'})

# %%
df1['errorBalanceOrig']=round(df1['newBalanceOrig']+df1['amount']-df1['oldBalanceOrig'])
df1['errorBalanceDest']=round(df1['oldBalanceDest']+df1['amount']-df1['newBalanceDest'])

# %%
for i in df.columns:
    print(i)
    print(np.unique(df[i]).shape)
    print('---------------------------------------------')
# Out:
# step
# (9,)
# ---------------------------------------------
# type
# (5,)
# ---------------------------------------------
# amount
# (42090,)
# ---------------------------------------------
# nameOrig
# (42271,)
# ---------------------------------------------
# oldBalanceOrig
# (26583,)
# ---------------------------------------------
# newBalanceOrig
# (21221,)
# ---------------------------------------------
# nameDest
# (24626,)
# ---------------------------------------------
# oldBalanceDest
# (20759,)
# ---------------------------------------------
# newBalanceDest
# (6941,)
# ---------------------------------------------
# isFraud
# (3,)
# ---------------------------------------------
# isFlaggedFraud
# (2,)
# ---------------------------------------------

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0.0    42176
# 1.0       94
# Name: count, dtype: int64

# %%
df1[df1['nameOrig']=='C2098525306'][['nameDest','amount','type','isFraud']]
# Out:
#           nameDest     amount      type  isFraud
# 48162  C1601211078  280613.05  CASH_OUT      0.0
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['amount']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'amount'}, axis=1)
#               .sort_values('amount', ascending=True))
#   xs = counted['amount']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_1.sort_values('amount', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('amount')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['isFraud']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'isFraud'}, axis=1)
#               .sort_values('isFraud', ascending=True))
#   xs = counted['isFraud']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('isFraud', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('isFraud')
# _ = plt.ylabel('count()')

# %%
np.sum(df1['nameOrig'].value_counts()>2)
# Out:
# 2

# %%
df1['nameDest'].value_counts()
# Out:
# nameDest
# C985934102     102
# C1286084959    102
# C665576141      98
# C248609774      94
# C1590550415     94
#               ...
# M1157743533      1
# M825581508       1
# M1589732509      1
# M1994527740      1
# C2116            1
# Name: count, Length: 1154949, dtype: int64
